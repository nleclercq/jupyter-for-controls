# %%
import numpy as np

# %%
from bokeh.layouts import gridplot
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import ColumnDataSource

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2778a118-f74f-422a-b478-f01c2e02b964">Loading BokehJS ...</span>
#     </div>

# %%
N = 300
x = np.linspace(0, 4*np.pi, N)
y1 = np.sin(x)
y2 = np.cos(x)

# %%
source = ColumnDataSource(data=dict(x=x, y1=y1, y2=y2))

# %%
TOOLS = "pan,wheel_zoom,box_zoom,reset,save,box_select,lasso_select"

s1 = figure(tools=TOOLS, plot_width=350, plot_height=350)
s1.scatter('x', 'y1', source=source)

# Linked brushing in Bokeh is expressed by sharing data sources between
# renderers. Note below that s2.scatter is called with the `source` 
# keyword argument, and supplied with the same data source from s1.scatter
s2 = figure(tools=TOOLS, plot_width=350, plot_height=350)
s2.circle('x', 'y2', source=source)
# Out:
# GlyphRenderer(id='e0e5d388-f5b5-4f96-b3bf-173570e57fc8', ...)

# %%
p = gridplot([[s1,s2]])
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="cf7c96c2-d53d-44a5-884c-3d57c0aa444e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("cf7c96c2-d53d-44a5-884c-3d57c0aa444e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cf7c96c2-d53d-44a5-884c-3d57c0aa444e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cf7c96c2-d53d-44a5-884c-3d57c0aa444e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1f2dae80-02f1-4fff-9da7-fcbb71ba514d":{"roots":{"references":[{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y1"}},"id":"4cfe08f1-5ab3-40b6-93a5-fe9dfe9ba9e3","type":"Circle"},{"attributes":{"below":[{"id":"ba4682b1-9ad9-4fab-bda3-db137de60239","type":"LinearAxis"}],"left":[{"id":"6b5b0b3f-8535-4d85-b605-eb9508212975","type":"LinearAxis"}],"plot_height":350,"plot_width":350,"renderers":[{"id":"ba4682b1-9ad9-4fab-bda3-db137de60239","type":"LinearAxis"},{"id":"63ec06b7-8ae7-43c1-800f-f86a5084f0ec","type":"Grid"},{"id":"6b5b0b3f-8535-4d85-b605-eb9508212975","type":"LinearAxis"},{"id":"70b49f87-533f-4693-b6e9-37f3f491787e","type":"Grid"},{"id":"ae574dfd-77dd-499b-889e-92a5d252fd24","type":"BoxAnnotation"},{"id":"3362ba92-5fb0-42ad-8653-06b3287fabc6","type":"BoxAnnotation"},{"id":"762d0e17-f6ee-4789-a2b2-ae0adaf1c65f","type":"PolyAnnotation"},{"id":"7feb2d55-eb71-402e-a82d-e69f68f9f1fd","type":"GlyphRenderer"}],"title":{"id":"578fb3da-311d-4935-83cb-ca87e7716a5a","type":"Title"},"tool_events":{"id":"8ad7cbf6-87d7-4c35-8774-99d87681020b","type":"ToolEvents"},"toolbar":{"id":"ddd00b32-6ede-417c-98c2-14cb00c259a3","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"bbaa0d58-2efe-4724-ba03-115ab175e7e0","type":"DataRange1d"},"y_range":{"id":"ce87e763-b705-42d4-9779-3238d2603cd9","type":"DataRange1d"}},"id":"ac9d5c9f-c98c-42b0-9d4c-fb7cf2fc92f8","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"overlay":{"id":"762d0e17-f6ee-4789-a2b2-ae0adaf1c65f","type":"PolyAnnotation"},"plot":{"id":"ac9d5c9f-c98c-42b0-9d4c-fb7cf2fc92f8","subtype":"Figure","type":"Plot"}},"id":"cf773586-fd2b-4b6d-b561-8d160e5fb8b3","type":"LassoSelectTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y1"}},"id":"fce37af7-1e02-4593-ab7b-89448f26cccd","type":"Circle"},{"attributes":{},"id":"8ad7cbf6-87d7-4c35-8774-99d87681020b","type":"ToolEvents"},{"attributes":{},"id":"9cf0eddc-a1b6-4c62-9b7c-f11f1a995a83","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"bbaa0d58-2efe-4724-ba03-115ab175e7e0","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"1768cf55-6de4-4ac1-adc6-c6ba02c108d7","type":"PanTool"},{"id":"8e162edc-3188-44cb-bfa0-8fd3667231c5","type":"WheelZoomTool"},{"id":"fc5aaaea-7b9d-42c0-900f-9e6305df4bed","type":"BoxZoomTool"},{"id":"2a278348-00d6-4511-8c2f-70dff9d3b122","type":"ResetTool"},{"id":"49f094b9-01fc-4074-a74d-d78a259ba25a","type":"SaveTool"},{"id":"65e76afb-65e4-4ffd-85fb-a7c6687ec50e","type":"BoxSelectTool"},{"id":"cf773586-fd2b-4b6d-b561-8d160e5fb8b3","type":"LassoSelectTool"}]},"id":"ddd00b32-6ede-417c-98c2-14cb00c259a3","type":"Toolbar"},{"attributes":{"plot":null,"text":""},"id":"578fb3da-311d-4935-83cb-ca87e7716a5a","type":"Title"},{"attributes":{"callback":null},"id":"ce87e763-b705-42d4-9779-3238d2603cd9","type":"DataRange1d"},{"attributes":{"formatter":{"id":"9cf0eddc-a1b6-4c62-9b7c-f11f1a995a83","type":"BasicTickFormatter"},"plot":{"id":"ac9d5c9f-c98c-42b0-9d4c-fb7cf2fc92f8","subtype":"Figure","type":"Plot"},"ticker":{"id":"36901703-ed48-4bc5-953f-9951f70fa754","type":"BasicTicker"}},"id":"ba4682b1-9ad9-4fab-bda3-db137de60239","type":"LinearAxis"},{"attributes":{},"id":"36901703-ed48-4bc5-953f-9951f70fa754","type":"BasicTicker"},{"attributes":{"data_source":{"id":"1dfef842-acae-491b-8d97-ef40b74d0210","type":"ColumnDataSource"},"glyph":{"id":"4cfe08f1-5ab3-40b6-93a5-fe9dfe9ba9e3","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"fce37af7-1e02-4593-ab7b-89448f26cccd","type":"Circle"},"selection_glyph":null},"id":"7feb2d55-eb71-402e-a82d-e69f68f9f1fd","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"ac9d5c9f-c98c-42b0-9d4c-fb7cf2fc92f8","subtype":"Figure","type":"Plot"},"ticker":{"id":"3690 ...
